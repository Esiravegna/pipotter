# %% [markdown]
# # Spell Detection
#
# ## Introduction
#
# Consider these symbols:
#
# <img src="https://i.pinimg.com/originals/c8/63/bc/c863bc6b913dbc49e094ee20eddec0ed.jpg" alt="Drawing" style="width: 300px;"/>
#
# When drawing with the PiNoir and using a reflective wand, they pretty much look like this:
#
# <img src="../../media/capture.png" style="width: 200px;">
#
# Not unlike a MNIST. Now, considering the fact that I had to draw the symbols myself, and even with the previous [augmenting](./corpus_augment.ipynb), let's create a really simple net so far.

# %% [markdown]
# ## The Model

# %%
# %matplotlib inline
import json
from keras.layers import Flatten, Dropout, Input, Dense
from keras.layers.advanced_activations import LeakyReLU, ELU
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau,
    TensorBoard,
)
import matplotlib.pyplot as plt

import os
# Out:
# Using TensorFlow backend.

# %%
NUMBER_OF_EPOCHS = 50
IMAGE_SHAPE = (32, 32, 1)

# %%
def spell_net(number_of_classess=6, input_shape=(32, 32, 3)):
    """
    Returns a single convoluted net for MNIST given a number_of_classes and an input shape
    """
    inputs = Input(shape=input_shape)
    x = Conv2D(
        32, (3, 3), strides=(2, 2), padding="valid", name="conv1", activation="relu"
    )(inputs)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name="pool1")(x)
    x = BatchNormalization()(x)
    x = Flatten()(x)
    x = Dense(32, activation="relu", use_bias=False)(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    predictions = Dense(number_of_classess, activation="sigmoid")(x)
    model = Model(inputs=inputs, outputs=predictions)
    print("spell net created")
    print(model.summary())
    return model

# %%
BATCH_SIZE = 64NUM_EPOCH = 50
LR = 0.0002  # initial learning rate
B1 = 0.5  # momentum term
GENERATED_MODEL_PATH = '../../wand/spell_net/models/'

# %%
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

train_generator = train_datagen.flow_from_directory(
    "../../media/dataset/train", target_size=(32, 32), batch_size=64
)
test_generator = train_datagen.flow_from_directory(
    "../../media/dataset/test", target_size=(32, 32), batch_size=BATCH_SIZE
)
# Out:
# Found 72000 images belonging to 6 classes.
# Found 18000 images belonging to 6 classes.

# %% [markdown]
# Let's create our list of classes

# %%
classes = {v: k for k, v in train_generator.class_indices.items()}
json.dumps(classes)
# Out:
# '{"0": "arresto_momentum", "1": "locomotor", "2": "lumos", "3": "meteojinx", "4": "noctis", "5": "silencio"}'

# %%
if not os.path.exists(GENERATED_MODEL_PATH):
    os.makedirs(GENERATED_MODEL_PATH)

# %%
train_callbacks = [
    EarlyStopping(monitor="val_loss", patience=25, verbose=0, mode="min"),
    ModelCheckpoint(
        filepath=os.path.join(GENERATED_MODEL_PATH, "spell_net_{epoch:02d}.h5"),
        verbose=1,
    ),
    TensorBoard(log_dir=GENERATED_MODEL_PATH, write_graph=False),
]
s = spell_net(number_of_classess=len(train_generator.class_indices.items()))
s.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
s.fit_generator(
    train_generator,
    steps_per_epoch=(len(train_generator.filenames)) // train_generator.batch_size,
    epochs=NUM_EPOCH,
    validation_data=test_generator,
    validation_steps=(len(test_generator.filenames)) // test_generator.batch_size,
    callbacks=train_callbacks,
    verbose=1,
)
# Out:
# spell net created
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 15, 15, 32)        896
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 7, 7, 32)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                50176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 51,526
# Trainable params: 51,398
# Non-trainable params: 128
# _________________________________________________________________
# None
# Epoch 1/50
# Epoch 00001: saving model to ../../wand/spell_net/models/spell_net_01.h5
# 1125/1125 [==============================] - 40s 35ms/step - loss: 0.3123 - acc: 0.9623 - val_loss: 0.0112 - val_acc: 0.9966
# Epoch 2/50
# Epoch 00002: saving model to ../../wand/spell_net/models/spell_net_02.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0528 - acc: 0.9875 - val_loss: 0.0068 - val_acc: 0.9976
# Epoch 3/50
# Epoch 00003: saving model to ../../wand/spell_net/models/spell_net_03.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0402 - acc: 0.9891 - val_loss: 0.0056 - val_acc: 0.9983
# Epoch 4/50
# Epoch 00004: saving model to ../../wand/spell_net/models/spell_net_04.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0322 - acc: 0.9907 - val_loss: 0.0038 - val_acc: 0.9988
# Epoch 5/50
# Epoch 00005: saving model to ../../wand/spell_net/models/spell_net_05.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0303 - acc: 0.9904 - val_loss: 0.0066 - val_acc: 0.9977
# Epoch 6/50
# Epoch 00006: saving model to ../../wand/spell_net/models/spell_net_06.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0274 - acc: 0.9916 - val_loss: 0.0128 - val_acc: 0.9957
# Epoch 7/50
# Epoch 00007: saving model to ../../wand/spell_net/models/spell_net_07.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0262 - acc: 0.9917 - val_loss: 0.0032 - val_acc: 0.9992
# Epoch 8/50
# Epoch 00008: saving model to ../../wand/spell_net/models/spell_net_08.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0258 - acc: 0.9913 - val_loss: 0.0057 - val_acc: 0.9983
# Epoch 9/50
# Epoch 00009: saving model to ../../wand/spell_net/models/spell_net_09.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0239 - acc: 0.9920 - val_loss: 0.0038 - val_acc: 0.9988
# Epoch 10/50
# Epoch 00018: saving model to ../../wand/spell_net/models/spell_net_18.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0192 - acc: 0.9937 - val_loss: 0.0046 - val_acc: 0.9986
# Epoch 19/50
# Epoch 00023: saving model to ../../wand/spell_net/models/spell_net_23.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0174 - acc: 0.9941 - val_loss: 0.0038 - val_acc: 0.9988
# Epoch 24/50
# Epoch 00027: saving model to ../../wand/spell_net/models/spell_net_27.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0179 - acc: 0.9940 - val_loss: 0.0043 - val_acc: 0.9988
# Epoch 28/50
# Epoch 00030: saving model to ../../wand/spell_net/models/spell_net_30.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0156 - acc: 0.9946 - val_loss: 0.0089 - val_acc: 0.9976
# Epoch 31/50
# Epoch 00031: saving model to ../../wand/spell_net/models/spell_net_31.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0156 - acc: 0.9946 - val_loss: 0.0023 - val_acc: 0.9991
# Epoch 32/50
# Epoch 00036: saving model to ../../wand/spell_net/models/spell_net_36.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0151 - acc: 0.9952 - val_loss: 0.0044 - val_acc: 0.9986
# Epoch 37/50
# Epoch 00040: saving model to ../../wand/spell_net/models/spell_net_40.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0162 - acc: 0.9945 - val_loss: 0.0026 - val_acc: 0.9989
# Epoch 41/50
# Epoch 00045: saving model to ../../wand/spell_net/models/spell_net_45.h5
# 1125/1125 [==============================] - 37s 32ms/step - loss: 0.0154 - acc: 0.9948 - val_loss: 0.0028 - val_acc: 0.9991
# Epoch 46/50
# Epoch 00050: saving model to ../../wand/spell_net/models/spell_net_50.h5
# 1125/1125 [==============================] - 37s 33ms/step - loss: 0.0140 - acc: 0.9955 - val_loss: 0.0049 - val_acc: 0.9987

# %% [markdown]
# Finally, our network is trained.
# The latest model can be found [here](https://s3.amazonaws.com/pipotter/spell_net/spell_net.tar.gz)
